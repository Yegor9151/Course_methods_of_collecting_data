# %% [markdown]
# # "Урок 4. Парсинг HTML. XPath"
#
# ## 1)Написать приложение, которое собирает основные новости с сайтов news.mail.ru, lenta.ru, yandex.news
#
# ### Для парсинга использовать xpath. Структура данных должна содержать:
# #### - название источника,
# #### - наименование новости,
# #### - ссылку на новость,
# #### - дата публикации
#
# ## 2)Сложить все новости в БД

# %%
import requests
import re
from lxml import html
from pymongo import MongoClient
from pprint import pprint
from datetime import datetime

# %%
header = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.113 Safari/537.36'}

# %%
class ManagerMongoDB:
    '''менеджер mongoDB'''

    client = MongoClient('localhost', 27017)  # Объявляем mongoDB
    db = client['news']  # создание БД

    def __init__(self, data):
        '''приём данных'''

        self.data = data

    def into_mongoDB(self):
        '''добавление данных в MongoDB'''

        news = self.db.news

        for d in self.data:
            news.update_one({'_id': d['_id']}, {'$set': d}, upsert=True)

        return news

    def show_result(self):
        '''показать результат'''

        result = []
        for i in self.into_mongoDB().find({}):
            result.append(i)

        return result

# %%
class NMParser:
    '''парсер news.mail.ru'''

    main_link = 'https://news.mail.ru/'

    def __init__(self, agent):
        '''получение user agent'''

        self.header = agent

    def get_html(self):
        '''получаем доступ к странице'''

        response = requests.get(self.main_link, headers=self.header)
        root = html.fromstring(response.text)

        return root

    def get_news(self, root):
        '''сбор названия и ссылки'''

        main = "//a[contains(@class,'js-topnews__item')]"

        path_lists = root.xpath(f"{main}/@href"), \
                     root.xpath("//ul[contains(@class,'list_half')]/li/a/@href")
        paths = []
        for path_list in path_lists:
            for path in path_list:
                paths.append(path)

        name_lists = root.xpath(f"{main}/span/span[contains(@class,'photo__title')]/text()"), \
                     root.xpath("//ul[contains(@class,'list_half')]/li/a/text()")
        names = []
        for name_list in name_lists:
            for name in name_list:
                names.append(name)

        return names, paths

    def edit_name(self, name):
        '''редактор имени'''

        pat = '\xa0'
        pattern = re.compile(pat)
        if pat in name:
            return re.sub(pattern, ' ', name)
        else:
            return name

    def time_source(self, link):
        '''собираем дату и источник'''

        response = requests.get(link, headers=self.header)
        root = html.fromstring(response.text)

        # источник
        try:
            source = root.xpath("//a[@class='link color_gray breadcrumbs__link']/span[@class='link__text']/text()")[0]
        except IndexError as e:
            source = None

        # дата публикации
        pattern = re.compile('\+[\d:]+')
        try:
            date_time = root.xpath("//span[@class='note__text breadcrumbs__text js-ago']/@datetime")[0]
            date_time = re.sub(pattern, '', re.sub('T', ' ', date_time))
        except IndexError as e:
            date_time = None

        return source, date_time

    def get_id(self, link):
        '''собираем id'''

        pattern = re.compile('/(\d+)/')
        
        return re.findall(pattern, link)

    def result(self):
        '''собираем данные'''

        root = self.get_html()
        news = self.get_news(root)
        
        result = []

        for n in range(len(news[0])):
            data_news = {}

            name = self.edit_name(news[0][n])
            link = self.main_link + news[1][n]
            source = self.time_source(link)[0]
            date_time = self.time_source(link)[1]
            id = self.get_id(link)[0]

            data_news['name'] = name
            data_news['link'] = link
            data_news['source'] = source
            data_news['date_time'] = date_time
            data_news['_id'] = id

            result.append(data_news)

        return result

# %%
NMdata = NMParser(header).result()

pprint(NMdata)
print(f'\nКоличество объектов: {len(NMdata)}')
# Out:
# [{'_id': '41450650',
#   'date_time': '2020-04-19 12:14:39',
#   'link': 'https://news.mail.ru//society/41450650/',
#   'name': 'В России за сутки заразились коронавирусом 6060 человек',
#   'source': 'Ведомости'},
#  {'_id': '41453467',
#   'date_time': '2020-04-19 17:03:58',
#   'link': 'https://news.mail.ru//society/41453467/',
#   'name': 'Ученые назвали тревожный симптом коронавируса',
#   'source': 'РИА Новости'},
#  {'_id': '41453715',
#   'date_time': '2020-04-19 17:21:55',
#   'link': 'https://news.mail.ru//incident/41453715/',
#   'name': 'В Москве арестован грузинский криминальный авторитет',
#   'source': 'Коммерсантъ'},
#  {'_id': '41450332',
#   'date_time': None,
#   'link': 'https://news.mail.ru/https://sportmail.ru/news/figure-skating/41450332/',
#   'name': 'Уехавший в США русский фигурист рассказал о панике американцев',
#   'source': None},
#  {'_id': '41453332',
#   'date_time': '2020-04-19 16:43:05',
#   'link': 'https://news.mail.ru//politics/41453332/',
#   'name': 'Российские военные испытали танк «Армата» в Сирии',
#   'source': 'Интерфакс'},
#  {'_id': '41450332',
#   'date_time': None,
#   'link': 'https://news.mail.ru/https://sportmail.ru/news/figure-skating/41450332/',
#   'name': 'Уехавший в США русский фигурист рассказал о панике американцев',
#   'source': None},
#  {'_id': '41453332',
#   'date_time': '2020-04-19 16:43:05',
#   'link': 'https://news.mail.ru//politics/41453332/',
#   'name': 'Российские военные испытали танк «Армата» в Сирии',
#   'source': 'Интерфакс'},
#  {'_id': '41452676',
#   'date_time': '2020-04-19 15:37:37',
#   'link': 'https://news.mail.ru//society/41452676/',
#   'name': 'Коронавирус оживил старый российский мем (фото)',
#   'source': 'Новости Mail.ru'},
#  {'_id': '41452177',
#   'date_time': '2020-04-19 16:01:11',
#   'link': 'https://news.mail.ru//politics/41452177/',
#   'name': 'Песков: наступило время, которое требует ручного управления',
#   'source': 'РИА Новости'},
#  {'_id': '41450047',
#   'date_time': '2020-04-19 10:55:35',
#   'link': 'https://news.mail.ru//society/41450047/',
#   'name': 'В РАН спрогнозировали масштаб второй волны коронавируса',
#   'source': 'm24.ru'},
#  {'_id': '41451890',
#   'date_time': '2020-04-19 13:43:58',
#   'link': 'https://news.mail.ru//society/41451890/',
#   'name': 'Ученые получили новые данные о бессимптомном протекании COVID-19',
#   'source': 'Новости Mail.ru'},
#  {'_id': '41453277',
#   'date_time': None,
#   'link': 'https://news.mail.ru/https://sportmail.ru/news/football-rus-premier/41453277/',
#   'name': 'РПЛ планирует возобновиться с середины июня по середину июля',
#   'source': None},
#  {'_id': '41453202',
#   'date_time': '2020-04-19 16:11:28',
#   'link': 'https://news.mail.ru//society/41453202/',
#   'name': 'Над Баварией появилось странное облако',
#   'source': 'Погода Mail.ru'}]
#
# Количество объектов: 13

# %%
mongo = ManagerMongoDB(NMdata).show_result()

pprint(mongo)
print(f'\nКоличество объектов: {len(mongo)}')
# Out:
# [{'_id': '41447768',
#   'date_time': '2020-04-18 23:46:54',
#   'link': 'https://news.mail.ru//society/41447768/',
#   'name': 'Пасхальное богослужение в храме Христа Спасителя',
#   'source': 'ТАСС'},
#  {'_id': '41445652',
#   'date_time': '2020-04-18 20:50:28',
#   'link': 'https://news.mail.ru//society/41445652/',
#   'name': 'Коронавирус COVID-19: главные события 18 апреля',
#   'source': 'Новости Mail.ru'},
#  {'_id': '41446112',
#   'date_time': '2020-04-18 19:58:11',
#   'link': 'https://news.mail.ru//economics/41446112/',
#   'name': 'Туристический сезон в Турции может быть открыт в конце мая',
#   'source': 'Коммерсантъ'},
#  {'_id': '41444458',
#   'date_time': '2020-04-18 17:36:29',
#   'link': 'https://news.mail.ru//society/41444458/',
#   'name': 'Что говорят предприниматели о карантине',
#   'source': 'Коммерсантъ'},
#  {'_id': '41444858',
#   'date_time': '2020-04-18 16:09:09',
#   'link': 'https://news.mail.ru//society/41444858/',
#   'name': 'COVID-19 породил новую экологическую проблему (фото)',
#   'source': 'Новости Mail.ru'},
#  {'_id': '41444334',
#   'date_time': '2020-04-18 16:55:28',
#   'link': 'https://news.mail.ru//incident/41444334/',
#   'name': 'Арестованы активы крупных российских компаний по вылову краба',
#   'source': 'Ведомости'},
#  {'_id': '41442103',
#   'date_time': '2020-04-18 12:58:34',
#   'link': 'https://news.mail.ru//society/41442103/',
#   'name': 'Путин разрешил принимать иностранцев без разрешения на работу',
#   'source': 'РИА Новости'},
#  {'_id': '41441693',
#   'date_time': '2020-04-18 10:47:11',
#   'link': 'https://news.mail.ru//incident/41441693/',
#   'name': 'В России за сутки выявлено более 4700 больных коронавирусом',
#   'source': 'Коммерсантъ'},
#  {'_id': '41447556',
#   'date_time': '2020-04-18 23:14:43',
#   'link': 'https://news.mail.ru//society/41447556/',
#   'name': 'Коронавирус: британские звезды устраивают большой онлайн-концерт',
#   'source': 'BBC News Русская служба'},
#  {'_id': '41442947',
#   'date_time': '2020-04-18 12:53:24',
#   'link': 'https://news.mail.ru//society/41442947/',
#   'name': 'Онищенко ответил на заявления Лукашенко о тестах на COVID-19',
#   'source': 'РИА Новости'},
#  {'_id': '41447158',
#   'date_time': '2020-04-18 21:32:11',
#   'link': 'https://news.mail.ru//incident/41447158/',
#   'name': 'В архангельской психбольнице зафиксировали вспышку коронавируса',
#   'source': 'ТАСС'},
#  {'_id': '41442413',
#   'date_time': '2020-04-18 12:04:03',
#   'link': 'https://news.mail.ru//society/41442413/',
#   'name': 'Россия вошла в топ-10 стран по числу заболевших вирусом COVID-19',
#   'source': 'Известия'},
#  {'_id': '41444717',
#   'date_time': '2020-04-18 16:05:22',
#   'link': 'https://news.mail.ru//economics/41444717/',
#   'name': 'Список пострадавших сфер экономики от пандемии расширен',
#   'source': 'Известия'},
#  {'_id': '41449639',
#   'date_time': '2020-04-19 09:20:49',
#   'link': 'https://news.mail.ru//politics/41449639/',
#   'name': 'Путин заявил о полном контроле над ситуацией с коронавирусом',
#   'source': 'РИА Новости'},
#  {'_id': '41448976',
#   'date_time': '2020-04-19 09:03:13',
#   'link': 'https://news.mail.ru//society/41448976/',
#   'name': 'Демограф оценила последствия коронавируса для рождаемости',
#   'source': 'Lenta.Ru'},
#  {'_id': '41448640',
#   'date_time': '2020-04-19 04:37:53',
#   'link': 'https://news.mail.ru//incident/41448640/',
#   'name': 'В Китае за сутки выявили 16 случаев заражения коронавирусом',
#   'source': 'РИА Новости'},
#  {'_id': '41448015',
#   'date_time': '2020-04-19 00:20:10',
#   'link': 'https://news.mail.ru//society/41448015/',
#   'name': 'Умер писатель и журналист Александр Кабаков',
#   'source': 'ТАСС'},
#  {'_id': '41447953',
#   'date_time': '2020-04-19 09:24:25',
#   'link': 'https://news.mail.ru//society/41447953/',
#   'name': 'Запад обвиняет Китай в искажении данных о коронавирусе',
#   'source': 'Lenta.Ru'},
#  {'_id': '41449362',
#   'date_time': '2020-04-19 08:28:22',
#   'link': 'https://news.mail.ru//economics/41449362/',
#   'name': 'США предрекли рекордный госдолг из-за коронавируса',
#   'source': 'Lenta.Ru'},
#  {'_id': '41447949',
#   'date_time': '2020-04-19 03:20:45',
#   'link': 'https://news.mail.ru//politics/41447949/',
#   'name': 'В Испании продлили режим повышенной готовности',
#   'source': 'Lenta.Ru'},
#  {'_id': '41448222',
#   'date_time': '2020-04-19 01:54:10',
#   'link': 'https://news.mail.ru//politics/41448222/',
#   'name': 'Трамп пообещал найти выделяемым ВОЗ $500 млн другое применение',
#   'source': 'ТАСС'},
#  {'_id': '41448412',
#   'date_time': '2020-04-19 03:09:35',
#   'link': 'https://news.mail.ru//economics/41448412/',
#   'name': 'Эксперт рассказал, как самозанятым получить кредитные каникулы',
#   'source': 'РИА Новости'},
#  {'_id': '41448888',
#   'date_time': '2020-04-19 06:37:25',
#   'link': 'https://news.mail.ru//incident/41448888/',
#   'name': 'Число жертв коронавируса в мире превысило 160 тысяч человек',
#   'source': 'Интерфакс'},
#  {'_id': '41449192',
#   'date_time': '2020-04-19 09:54:35',
#   'link': 'https://news.mail.ru//incident/41449192/',
#   'name': 'СМИ: США закупили респираторы по завышенной стоимости',
#   'source': 'ТАСС'},
#  {'_id': '41450074',
#   'date_time': '2020-04-19 10:30:27',
#   'link': 'https://news.mail.ru//politics/41450074/',
#   'name': 'Глава лаборатории в Ухане отверг обвинения в создании вируса',
#   'source': 'Lenta.Ru'},
#  {'_id': '41448505',
#   'date_time': 'Не получилось собрать дату публикации (тип ошибки: list index '
#                'out of range)',
#   'link': 'https://news.mail.ru/https://sportmail.ru/news/football-eurocups/41448505/',
#   'name': 'Стали известны даты возобновления Лиги чемпионов и Лиги Европы',
#   'source': 'Не получилось собрать источник публикации (тип ошибки: list index '
#             'out of range)'},
#  {'_id': '41448769',
#   'date_time': '2020-04-19 10:04:14',
#   'link': 'https://news.mail.ru//society/41448769/',
#   'name': 'Вулкан Ключевской выбросил потоки лавы (видео)',
#   'source': 'РИА Новости'},
#  {'_id': '41450650',
#   'date_time': '2020-04-19 12:14:39',
#   'link': 'https://news.mail.ru//society/41450650/',
#   'name': 'В России за сутки заразились коронавирусом 6060 человек',
#   'source': 'Ведомости'},
#  {'_id': '41452413',
#   'date_time': '2020-04-19 14:23:05',
#   'link': 'https://news.mail.ru//politics/41452413/',
#   'name': 'Песков рассказал, когда Россия выйдет на плато по коронавирусу',
#   'source': 'Известия'},
#  {'_id': '41450332',
#   'date_time': None,
#   'link': 'https://news.mail.ru/https://sportmail.ru/news/figure-skating/41450332/',
#   'name': 'Уехавший в США русский фигурист рассказал о панике американцев',
#   'source': None},
#  {'_id': '41451890',
#   'date_time': '2020-04-19 13:43:58',
#   'link': 'https://news.mail.ru//society/41451890/',
#   'name': 'Ученые получили новые данные о бессимптомном протекании COVID-19',
#   'source': 'Новости Mail.ru'},
#  {'_id': '41450047',
#   'date_time': '2020-04-19 10:55:35',
#   'link': 'https://news.mail.ru//society/41450047/',
#   'name': 'В РАН спрогнозировали масштаб второй волны коронавируса',
#   'source': 'm24.ru'},
#  {'_id': '41452118',
#   'date_time': '2020-04-19 14:34:53',
#   'link': 'https://news.mail.ru//politics/41452118/',
#   'name': 'Путин прокомментировал страхи по поводу возрождения СССР',
#   'source': 'ТАСС'},
#  {'_id': '41449873',
#   'date_time': '2020-04-19 10:41:12',
#   'link': 'https://news.mail.ru//society/41449873/',
#   'name': 'Насколько по-разному пандемия влияет на мужчин и женщин и почему',
#   'source': 'BBC News Русская служба'},
#  {'_id': '41451806',
#   'date_time': '2020-04-19 13:42:44',
#   'link': 'https://news.mail.ru//society/41451806/',
#   'name': 'Чубайс предсказал падение числа заражений коронавирусом в мае',
#   'source': 'Forbes'},
#  {'_id': '41450130',
#   'date_time': '2020-04-19 12:37:16',
#   'link': 'https://news.mail.ru//society/41450130/',
#   'name': 'Историк высмеял миф о насилии армии СССР над жителями Германии',
#   'source': 'РИА Новости'},
#  {'_id': '41450704',
#   'date_time': '2020-04-19 11:25:45',
#   'link': 'https://news.mail.ru//society/41450704/',
#   'name': 'В ЮАР на безлюдные улицы вышли пингвины (видео)',
#   'source': 'Новости Mail.ru'},
#  {'_id': '41452177',
#   'date_time': '2020-04-19 16:01:11',
#   'link': 'https://news.mail.ru//politics/41452177/',
#   'name': 'Песков: наступило время, которое требует ручного управления',
#   'source': 'РИА Новости'},
#  {'_id': '41452676',
#   'date_time': '2020-04-19 15:37:37',
#   'link': 'https://news.mail.ru//society/41452676/',
#   'name': 'Коронавирус оживил старый российский мем (фото)',
#   'source': 'Новости Mail.ru'},
#  {'_id': '41448513',
#   'date_time': '2020-04-19 14:18:53',
#   'link': 'https://news.mail.ru//society/41448513/',
#   'name': 'МЧС советует после покупки замачивать в воде овощи и зелень',
#   'source': 'ТАСС'},
#  {'_id': '41452605',
#   'date_time': '2020-04-19 15:19:00',
#   'link': 'https://news.mail.ru//economics/41452605/',
#   'name': 'Силуанов: в ФНБ к концу года останется 7 трлн рублей',
#   'source': 'Интерфакс'},
#  {'_id': '41453332',
#   'date_time': '2020-04-19 16:43:05',
#   'link': 'https://news.mail.ru//politics/41453332/',
#   'name': 'Российские военные испытали танк «Армата» в Сирии',
#   'source': 'Интерфакс'},
#  {'_id': '41453277',
#   'date_time': None,
#   'link': 'https://news.mail.ru/https://sportmail.ru/news/football-rus-premier/41453277/',
#   'name': 'РПЛ планирует возобновиться с середины июня по середину июля',
#   'source': None},
#  {'_id': '41453202',
#   'date_time': '2020-04-19 16:11:28',
#   'link': 'https://news.mail.ru//society/41453202/',
#   'name': 'Над Баварией появилось странное облако',
#   'source': 'Погода Mail.ru'},
#  {'_id': '41452672',
#   'date_time': '2020-04-19 16:35:56',
#   'link': 'https://news.mail.ru//economics/41452672/',
#   'name': 'Орешкин дал негативный прогноз на второй квартал по экономике',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/armata',
#   'date_time': '2020-04-19 16:40:00',
#   'link': 'https://lenta.ru//news/2020/04/19/armata/',
#   'name': 'Россия испытала танк «Армата» в Сирии',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/dog',
#   'date_time': '2020-04-19 17:26:00',
#   'link': 'https://lenta.ru//news/2020/04/19/dog/',
#   'name': 'Мужчина нашел на шоссе собаку с трогательной запиской и расплакался',
#   'source': 'Источник отсутствует'},
#  {'_id': '2020/04/19/aurus',
#   'date_time': '2020-04-19 17:11:06',
#   'link': 'https://lenta.ru//news/2020/04/19/aurus/',
#   'name': 'Стали известны сроки первой поставки машин из «Кортежа» Путина',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/chestno',
#   'date_time': '2020-04-19 17:03:00',
#   'link': 'https://lenta.ru//news/2020/04/19/chestno/',
#   'name': 'Идущий на шестой срок Лукашенко пообещал честные выборы',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/reanim',
#   'date_time': '2020-04-19 16:58:00',
#   'link': 'https://lenta.ru//news/2020/04/19/reanim/',
#   'name': 'Малышева показала реанимацию пациента в больнице с зараженными '
#           'коронавирусом',
#   'source': None},
#  {'_id': '2020/04/19/msk',
#   'date_time': '2020-04-19 16:30:00',
#   'link': 'https://lenta.ru//news/2020/04/19/msk/',
#   'name': 'Охлобыстин атаковал журналистку на пасхальной службе «для '
#           'избранных» в Москве',
#   'source': None},
#  {'_id': None,
#   'date_time': None,
#   'link': 'https://moslenta.ru/news/obnarodovana-novaya-statistika-po-koronavirusu-v-moskve-19-04-2020.htm/?utm_source=from_lenta',
#   'name': 'Обнародована новая статистика по коронавирусу в Москве ',
#   'source': None},
#  {'_id': '2020/04/19/easter2',
#   'date_time': '2020-04-19 16:11:00',
#   'link': 'https://lenta.ru//news/2020/04/19/easter2/',
#   'name': 'На службе «для избранных» в храме у Кремля молились прихожане на '
#           'Porsche',
#   'source': 'Источник отсутствует'},
#  {'_id': '2020/04/19/debilizacia',
#   'date_time': '2020-04-19 16:00:00',
#   'link': 'https://lenta.ru//news/2020/04/19/debilizacia/',
#   'name': 'Гузеева констатировала дебилизацию в стране',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/siluanov',
#   'date_time': '2020-04-19 15:14:00',
#   'link': 'https://lenta.ru//news/2020/04/19/siluanov/',
#   'name': 'Назван срок истощения российской «кубышки»',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/prognoz',
#   'date_time': '2020-04-19 17:29:43',
#   'link': 'https://lenta.ru//news/2020/04/19/prognoz/',
#   'name': 'Названы сроки возврата к нормальной жизни после эпидемии '
#           'коронавируса в России',
#   'source': 'РИА Новости'},
#  {'_id': '41453715',
#   'date_time': '2020-04-19 17:21:55',
#   'link': 'https://news.mail.ru//incident/41453715/',
#   'name': 'В Москве арестован грузинский криминальный авторитет',
#   'source': 'Коммерсантъ'},
#  {'_id': '41453467',
#   'date_time': '2020-04-19 17:03:58',
#   'link': 'https://news.mail.ru//society/41453467/',
#   'name': 'Ученые назвали тревожный симптом коронавируса',
#   'source': 'РИА Новости'}]
#
# Количество объектов: 58

# %%
class LParser:
    '''парсер lenta.ru'''
    
    main_link = 'https://lenta.ru/'
    
    def __init__(self, agent):
        '''получение user agent'''

        self.header = agent
        
    def get_html(self):
        '''получаем доступ к странице'''

        response = requests.get(self.main_link, headers=self.header)
        root = html.fromstring(response.text)

        return root
    
    def get_news(self, root):
        '''название и ссылка'''
        
        main = "//section[contains(@class,'b-top7-for-main')]/div/div[contains(@class,'item')]"
        
        name_lists = root.xpath(f"{main}/h2/a/text()"), \
                    root.xpath(f"{main}/a/text()")
        
        names = []
        for name_list in name_lists:
            for name in name_list:
                names.append(name)
                
        links = root.xpath(f"{main}/a/@href")
        
        return names, links
    
    def edit_name(self, name):
        '''редактор имени'''

        pat = '\xa0'
        pattern = re.compile(pat)
        if pat in name:
            return re.sub(pattern, ' ', name)
        else:
            return name
        
    def time_source(self, link):
        '''собираем дату и источник'''

        response = requests.get(link, headers=self.header)
        root = html.fromstring(response.text)
        
        # источник
        try:
            source = root.xpath("//div[@class='b-label__credits']/text()")[0]
            Spattern1 = re.compile('.+/ ')
            Spattern2 = re.compile('.+')
            if '/' in source:
                source = re.sub(Spattern1, '', source)
            else:
                source = re.sub(Spattern2, 'Источник отсутствует', source)
        except IndexError as e:
            source = None
        
        # дата и время
        DTpattern = re.compile('\+[\d:]+')
        try:
            date_time = root.xpath("//time[@class='g-date']/@datetime")[0]
            date_time = re.sub(DTpattern, '', re.sub('T', ' ', date_time))
        except IndexError as e:
            date_time = None
        
        return source, date_time
    
    def get_id(self, link):
        '''собираем id'''

        pattern = re.compile('([/\d+]{10}/[\w]+)')
        return re.findall(pattern, link)
        
    def result(self):
        '''робираем данные'''
        
        root = self.get_html()
        news = self.get_news(root)
        result = []

        for n in range(len(news[0])):
            data_news = {}

            name = self.edit_name(news[0][n])
            if 'http' in news[1][n]:
                link = news[1][n]
            else:
                link = self.main_link + news[1][n]
            source = self.time_source(link)[0]
            date_time = self.time_source(link)[1]
            try:
                id = self.get_id(link)[0]
            except IndexError:
                id = None
            
            data_news['name'] = name
            data_news['link'] = link
            data_news['source'] = source
            data_news['date_time'] = date_time
            data_news['_id'] = id

            result.append(data_news)
        
        return result

# %%
Ldata = LParser(header).result()

pprint(Ldata)
print(f'\nКоличество объектов: {len(Ldata)}')
# Out:
# [{'_id': '2020/04/19/armata',
#   'date_time': '2020-04-19 16:40:00',
#   'link': 'https://lenta.ru//news/2020/04/19/armata/',
#   'name': 'Россия испытала танк «Армата» в Сирии',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/prognoz',
#   'date_time': '2020-04-19 17:29:43',
#   'link': 'https://lenta.ru//news/2020/04/19/prognoz/',
#   'name': 'Названы сроки возврата к нормальной жизни после эпидемии '
#           'коронавируса в России',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/dog',
#   'date_time': '2020-04-19 17:26:00',
#   'link': 'https://lenta.ru//news/2020/04/19/dog/',
#   'name': 'Мужчина нашел на шоссе собаку с трогательной запиской и расплакался',
#   'source': 'Источник отсутствует'},
#  {'_id': '2020/04/19/aurus',
#   'date_time': '2020-04-19 17:11:06',
#   'link': 'https://lenta.ru//news/2020/04/19/aurus/',
#   'name': 'Стали известны сроки первой поставки машин из «Кортежа» Путина',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/chestno',
#   'date_time': '2020-04-19 17:03:00',
#   'link': 'https://lenta.ru//news/2020/04/19/chestno/',
#   'name': 'Идущий на шестой срок Лукашенко пообещал честные выборы',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/reanim',
#   'date_time': '2020-04-19 16:58:00',
#   'link': 'https://lenta.ru//news/2020/04/19/reanim/',
#   'name': 'Малышева показала реанимацию пациента в больнице с зараженными '
#           'коронавирусом',
#   'source': None},
#  {'_id': '2020/04/19/msk',
#   'date_time': '2020-04-19 16:30:00',
#   'link': 'https://lenta.ru//news/2020/04/19/msk/',
#   'name': 'Охлобыстин атаковал журналистку на пасхальной службе «для '
#           'избранных» в Москве',
#   'source': None},
#  {'_id': None,
#   'date_time': None,
#   'link': 'https://moslenta.ru/news/obnarodovana-novaya-statistika-po-koronavirusu-v-moskve-19-04-2020.htm/?utm_source=from_lenta',
#   'name': 'Обнародована новая статистика по коронавирусу в Москве ',
#   'source': None},
#  {'_id': '2020/04/19/easter2',
#   'date_time': '2020-04-19 16:11:00',
#   'link': 'https://lenta.ru//news/2020/04/19/easter2/',
#   'name': 'На службе «для избранных» в храме у Кремля молились прихожане на '
#           'Porsche',
#   'source': 'Источник отсутствует'},
#  {'_id': '2020/04/19/siluanov',
#   'date_time': '2020-04-19 15:14:00',
#   'link': 'https://lenta.ru//news/2020/04/19/siluanov/',
#   'name': 'Назван срок истощения российской «кубышки»',
#   'source': 'РИА Новости'}]
#
# Количество объектов: 10

# %%
mongo = ManagerMongoDB(Ldata).show_result()

pprint(mongo)
print(f'\nКоличество объектов: {len(mongo)}')
# Out:
# [{'_id': '41447768',
#   'date_time': '2020-04-18 23:46:54',
#   'link': 'https://news.mail.ru//society/41447768/',
#   'name': 'Пасхальное богослужение в храме Христа Спасителя',
#   'source': 'ТАСС'},
#  {'_id': '41445652',
#   'date_time': '2020-04-18 20:50:28',
#   'link': 'https://news.mail.ru//society/41445652/',
#   'name': 'Коронавирус COVID-19: главные события 18 апреля',
#   'source': 'Новости Mail.ru'},
#  {'_id': '41446112',
#   'date_time': '2020-04-18 19:58:11',
#   'link': 'https://news.mail.ru//economics/41446112/',
#   'name': 'Туристический сезон в Турции может быть открыт в конце мая',
#   'source': 'Коммерсантъ'},
#  {'_id': '41444458',
#   'date_time': '2020-04-18 17:36:29',
#   'link': 'https://news.mail.ru//society/41444458/',
#   'name': 'Что говорят предприниматели о карантине',
#   'source': 'Коммерсантъ'},
#  {'_id': '41444858',
#   'date_time': '2020-04-18 16:09:09',
#   'link': 'https://news.mail.ru//society/41444858/',
#   'name': 'COVID-19 породил новую экологическую проблему (фото)',
#   'source': 'Новости Mail.ru'},
#  {'_id': '41444334',
#   'date_time': '2020-04-18 16:55:28',
#   'link': 'https://news.mail.ru//incident/41444334/',
#   'name': 'Арестованы активы крупных российских компаний по вылову краба',
#   'source': 'Ведомости'},
#  {'_id': '41442103',
#   'date_time': '2020-04-18 12:58:34',
#   'link': 'https://news.mail.ru//society/41442103/',
#   'name': 'Путин разрешил принимать иностранцев без разрешения на работу',
#   'source': 'РИА Новости'},
#  {'_id': '41441693',
#   'date_time': '2020-04-18 10:47:11',
#   'link': 'https://news.mail.ru//incident/41441693/',
#   'name': 'В России за сутки выявлено более 4700 больных коронавирусом',
#   'source': 'Коммерсантъ'},
#  {'_id': '41447556',
#   'date_time': '2020-04-18 23:14:43',
#   'link': 'https://news.mail.ru//society/41447556/',
#   'name': 'Коронавирус: британские звезды устраивают большой онлайн-концерт',
#   'source': 'BBC News Русская служба'},
#  {'_id': '41442947',
#   'date_time': '2020-04-18 12:53:24',
#   'link': 'https://news.mail.ru//society/41442947/',
#   'name': 'Онищенко ответил на заявления Лукашенко о тестах на COVID-19',
#   'source': 'РИА Новости'},
#  {'_id': '41447158',
#   'date_time': '2020-04-18 21:32:11',
#   'link': 'https://news.mail.ru//incident/41447158/',
#   'name': 'В архангельской психбольнице зафиксировали вспышку коронавируса',
#   'source': 'ТАСС'},
#  {'_id': '41442413',
#   'date_time': '2020-04-18 12:04:03',
#   'link': 'https://news.mail.ru//society/41442413/',
#   'name': 'Россия вошла в топ-10 стран по числу заболевших вирусом COVID-19',
#   'source': 'Известия'},
#  {'_id': '41444717',
#   'date_time': '2020-04-18 16:05:22',
#   'link': 'https://news.mail.ru//economics/41444717/',
#   'name': 'Список пострадавших сфер экономики от пандемии расширен',
#   'source': 'Известия'},
#  {'_id': '41449639',
#   'date_time': '2020-04-19 09:20:49',
#   'link': 'https://news.mail.ru//politics/41449639/',
#   'name': 'Путин заявил о полном контроле над ситуацией с коронавирусом',
#   'source': 'РИА Новости'},
#  {'_id': '41448976',
#   'date_time': '2020-04-19 09:03:13',
#   'link': 'https://news.mail.ru//society/41448976/',
#   'name': 'Демограф оценила последствия коронавируса для рождаемости',
#   'source': 'Lenta.Ru'},
#  {'_id': '41448640',
#   'date_time': '2020-04-19 04:37:53',
#   'link': 'https://news.mail.ru//incident/41448640/',
#   'name': 'В Китае за сутки выявили 16 случаев заражения коронавирусом',
#   'source': 'РИА Новости'},
#  {'_id': '41448015',
#   'date_time': '2020-04-19 00:20:10',
#   'link': 'https://news.mail.ru//society/41448015/',
#   'name': 'Умер писатель и журналист Александр Кабаков',
#   'source': 'ТАСС'},
#  {'_id': '41447953',
#   'date_time': '2020-04-19 09:24:25',
#   'link': 'https://news.mail.ru//society/41447953/',
#   'name': 'Запад обвиняет Китай в искажении данных о коронавирусе',
#   'source': 'Lenta.Ru'},
#  {'_id': '41449362',
#   'date_time': '2020-04-19 08:28:22',
#   'link': 'https://news.mail.ru//economics/41449362/',
#   'name': 'США предрекли рекордный госдолг из-за коронавируса',
#   'source': 'Lenta.Ru'},
#  {'_id': '41447949',
#   'date_time': '2020-04-19 03:20:45',
#   'link': 'https://news.mail.ru//politics/41447949/',
#   'name': 'В Испании продлили режим повышенной готовности',
#   'source': 'Lenta.Ru'},
#  {'_id': '41448222',
#   'date_time': '2020-04-19 01:54:10',
#   'link': 'https://news.mail.ru//politics/41448222/',
#   'name': 'Трамп пообещал найти выделяемым ВОЗ $500 млн другое применение',
#   'source': 'ТАСС'},
#  {'_id': '41448412',
#   'date_time': '2020-04-19 03:09:35',
#   'link': 'https://news.mail.ru//economics/41448412/',
#   'name': 'Эксперт рассказал, как самозанятым получить кредитные каникулы',
#   'source': 'РИА Новости'},
#  {'_id': '41448888',
#   'date_time': '2020-04-19 06:37:25',
#   'link': 'https://news.mail.ru//incident/41448888/',
#   'name': 'Число жертв коронавируса в мире превысило 160 тысяч человек',
#   'source': 'Интерфакс'},
#  {'_id': '41449192',
#   'date_time': '2020-04-19 09:54:35',
#   'link': 'https://news.mail.ru//incident/41449192/',
#   'name': 'СМИ: США закупили респираторы по завышенной стоимости',
#   'source': 'ТАСС'},
#  {'_id': '41450074',
#   'date_time': '2020-04-19 10:30:27',
#   'link': 'https://news.mail.ru//politics/41450074/',
#   'name': 'Глава лаборатории в Ухане отверг обвинения в создании вируса',
#   'source': 'Lenta.Ru'},
#  {'_id': '41448505',
#   'date_time': 'Не получилось собрать дату публикации (тип ошибки: list index '
#                'out of range)',
#   'link': 'https://news.mail.ru/https://sportmail.ru/news/football-eurocups/41448505/',
#   'name': 'Стали известны даты возобновления Лиги чемпионов и Лиги Европы',
#   'source': 'Не получилось собрать источник публикации (тип ошибки: list index '
#             'out of range)'},
#  {'_id': '41448769',
#   'date_time': '2020-04-19 10:04:14',
#   'link': 'https://news.mail.ru//society/41448769/',
#   'name': 'Вулкан Ключевской выбросил потоки лавы (видео)',
#   'source': 'РИА Новости'},
#  {'_id': '41450650',
#   'date_time': '2020-04-19 12:14:39',
#   'link': 'https://news.mail.ru//society/41450650/',
#   'name': 'В России за сутки заразились коронавирусом 6060 человек',
#   'source': 'Ведомости'},
#  {'_id': '41452413',
#   'date_time': '2020-04-19 14:23:05',
#   'link': 'https://news.mail.ru//politics/41452413/',
#   'name': 'Песков рассказал, когда Россия выйдет на плато по коронавирусу',
#   'source': 'Известия'},
#  {'_id': '41450332',
#   'date_time': None,
#   'link': 'https://news.mail.ru/https://sportmail.ru/news/figure-skating/41450332/',
#   'name': 'Уехавший в США русский фигурист рассказал о панике американцев',
#   'source': None},
#  {'_id': '41451890',
#   'date_time': '2020-04-19 13:43:58',
#   'link': 'https://news.mail.ru//society/41451890/',
#   'name': 'Ученые получили новые данные о бессимптомном протекании COVID-19',
#   'source': 'Новости Mail.ru'},
#  {'_id': '41450047',
#   'date_time': '2020-04-19 10:55:35',
#   'link': 'https://news.mail.ru//society/41450047/',
#   'name': 'В РАН спрогнозировали масштаб второй волны коронавируса',
#   'source': 'm24.ru'},
#  {'_id': '41452118',
#   'date_time': '2020-04-19 14:34:53',
#   'link': 'https://news.mail.ru//politics/41452118/',
#   'name': 'Путин прокомментировал страхи по поводу возрождения СССР',
#   'source': 'ТАСС'},
#  {'_id': '41449873',
#   'date_time': '2020-04-19 10:41:12',
#   'link': 'https://news.mail.ru//society/41449873/',
#   'name': 'Насколько по-разному пандемия влияет на мужчин и женщин и почему',
#   'source': 'BBC News Русская служба'},
#  {'_id': '41451806',
#   'date_time': '2020-04-19 13:42:44',
#   'link': 'https://news.mail.ru//society/41451806/',
#   'name': 'Чубайс предсказал падение числа заражений коронавирусом в мае',
#   'source': 'Forbes'},
#  {'_id': '41450130',
#   'date_time': '2020-04-19 12:37:16',
#   'link': 'https://news.mail.ru//society/41450130/',
#   'name': 'Историк высмеял миф о насилии армии СССР над жителями Германии',
#   'source': 'РИА Новости'},
#  {'_id': '41450704',
#   'date_time': '2020-04-19 11:25:45',
#   'link': 'https://news.mail.ru//society/41450704/',
#   'name': 'В ЮАР на безлюдные улицы вышли пингвины (видео)',
#   'source': 'Новости Mail.ru'},
#  {'_id': '41452177',
#   'date_time': '2020-04-19 16:01:11',
#   'link': 'https://news.mail.ru//politics/41452177/',
#   'name': 'Песков: наступило время, которое требует ручного управления',
#   'source': 'РИА Новости'},
#  {'_id': '41452676',
#   'date_time': '2020-04-19 15:37:37',
#   'link': 'https://news.mail.ru//society/41452676/',
#   'name': 'Коронавирус оживил старый российский мем (фото)',
#   'source': 'Новости Mail.ru'},
#  {'_id': '41448513',
#   'date_time': '2020-04-19 14:18:53',
#   'link': 'https://news.mail.ru//society/41448513/',
#   'name': 'МЧС советует после покупки замачивать в воде овощи и зелень',
#   'source': 'ТАСС'},
#  {'_id': '41452605',
#   'date_time': '2020-04-19 15:19:00',
#   'link': 'https://news.mail.ru//economics/41452605/',
#   'name': 'Силуанов: в ФНБ к концу года останется 7 трлн рублей',
#   'source': 'Интерфакс'},
#  {'_id': '41453332',
#   'date_time': '2020-04-19 16:43:05',
#   'link': 'https://news.mail.ru//politics/41453332/',
#   'name': 'Российские военные испытали танк «Армата» в Сирии',
#   'source': 'Интерфакс'},
#  {'_id': '41453277',
#   'date_time': None,
#   'link': 'https://news.mail.ru/https://sportmail.ru/news/football-rus-premier/41453277/',
#   'name': 'РПЛ планирует возобновиться с середины июня по середину июля',
#   'source': None},
#  {'_id': '41453202',
#   'date_time': '2020-04-19 16:11:28',
#   'link': 'https://news.mail.ru//society/41453202/',
#   'name': 'Над Баварией появилось странное облако',
#   'source': 'Погода Mail.ru'},
#  {'_id': '41452672',
#   'date_time': '2020-04-19 16:35:56',
#   'link': 'https://news.mail.ru//economics/41452672/',
#   'name': 'Орешкин дал негативный прогноз на второй квартал по экономике',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/armata',
#   'date_time': '2020-04-19 16:40:00',
#   'link': 'https://lenta.ru//news/2020/04/19/armata/',
#   'name': 'Россия испытала танк «Армата» в Сирии',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/dog',
#   'date_time': '2020-04-19 17:26:00',
#   'link': 'https://lenta.ru//news/2020/04/19/dog/',
#   'name': 'Мужчина нашел на шоссе собаку с трогательной запиской и расплакался',
#   'source': 'Источник отсутствует'},
#  {'_id': '2020/04/19/aurus',
#   'date_time': '2020-04-19 17:11:06',
#   'link': 'https://lenta.ru//news/2020/04/19/aurus/',
#   'name': 'Стали известны сроки первой поставки машин из «Кортежа» Путина',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/chestno',
#   'date_time': '2020-04-19 17:03:00',
#   'link': 'https://lenta.ru//news/2020/04/19/chestno/',
#   'name': 'Идущий на шестой срок Лукашенко пообещал честные выборы',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/reanim',
#   'date_time': '2020-04-19 16:58:00',
#   'link': 'https://lenta.ru//news/2020/04/19/reanim/',
#   'name': 'Малышева показала реанимацию пациента в больнице с зараженными '
#           'коронавирусом',
#   'source': None},
#  {'_id': '2020/04/19/msk',
#   'date_time': '2020-04-19 16:30:00',
#   'link': 'https://lenta.ru//news/2020/04/19/msk/',
#   'name': 'Охлобыстин атаковал журналистку на пасхальной службе «для '
#           'избранных» в Москве',
#   'source': None},
#  {'_id': None,
#   'date_time': None,
#   'link': 'https://moslenta.ru/news/obnarodovana-novaya-statistika-po-koronavirusu-v-moskve-19-04-2020.htm/?utm_source=from_lenta',
#   'name': 'Обнародована новая статистика по коронавирусу в Москве ',
#   'source': None},
#  {'_id': '2020/04/19/easter2',
#   'date_time': '2020-04-19 16:11:00',
#   'link': 'https://lenta.ru//news/2020/04/19/easter2/',
#   'name': 'На службе «для избранных» в храме у Кремля молились прихожане на '
#           'Porsche',
#   'source': 'Источник отсутствует'},
#  {'_id': '2020/04/19/debilizacia',
#   'date_time': '2020-04-19 16:00:00',
#   'link': 'https://lenta.ru//news/2020/04/19/debilizacia/',
#   'name': 'Гузеева констатировала дебилизацию в стране',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/siluanov',
#   'date_time': '2020-04-19 15:14:00',
#   'link': 'https://lenta.ru//news/2020/04/19/siluanov/',
#   'name': 'Назван срок истощения российской «кубышки»',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/prognoz',
#   'date_time': '2020-04-19 17:29:43',
#   'link': 'https://lenta.ru//news/2020/04/19/prognoz/',
#   'name': 'Названы сроки возврата к нормальной жизни после эпидемии '
#           'коронавируса в России',
#   'source': 'РИА Новости'},
#  {'_id': '41453715',
#   'date_time': '2020-04-19 17:21:55',
#   'link': 'https://news.mail.ru//incident/41453715/',
#   'name': 'В Москве арестован грузинский криминальный авторитет',
#   'source': 'Коммерсантъ'},
#  {'_id': '41453467',
#   'date_time': '2020-04-19 17:03:58',
#   'link': 'https://news.mail.ru//society/41453467/',
#   'name': 'Ученые назвали тревожный симптом коронавируса',
#   'source': 'РИА Новости'}]
#
# Количество объектов: 58

# %%
class YaParser:
    '''парсер news.mail.ru'''

    main_link = 'https://yandex.ru/news/'

    def __init__(self, agent):
        '''получение user agent'''

        self.header = agent
        
    def get_html(self):
        '''получаем доступ к странице'''

        response = requests.get(self.main_link, headers=self.header)
        root = html.fromstring(response.text)

        return root
    
    def get_news(self, root):
        '''сбор названия и ссылки'''

        main = "//div[@class='card__body']"
        
        # названия
        name_list = root.xpath(f"{main}/a/h2/span/text()")
        
        # ссылки
        path_lists = root.xpath(f"{main}/a/@href")
        
        # источник
        source = root.xpath(f"{main}/footer/div/a/span[@class='card__source-name']/text()")
        
        # время публикации
        date_time = root.xpath(f"{main}/footer/div/a/span[contains(@class,'sport-date')]/text()")
                                
        return name_list, path_lists, source, date_time
    
    def get_id(self, link):
        '''собираем id'''

        pattern = re.compile('id=(\d+)')
        
        return re.findall(pattern, link)[0]
        
    def result(self):
        '''собираем данные'''
        
        root = self.get_html()
        news = self.get_news(root)
        
        result = []
        
        for n in range(len(news[0])):
            data_news = {}

            name = news[0][n]
            link = news[1][n]
            source = news[2][n]
            date_time = f"{datetime.now().date()} {news[3][n]}"
            id = self.get_id(link)

            data_news['name'] = name
            data_news['link'] = link
            data_news['source'] = source
            data_news['date_time'] = date_time
            data_news['_id'] = id

            result.append(data_news)

        return result

# %%
while True:
    Yadata = YaParser(header).result()
    if len(Yadata) != 0:
        break

pprint(Yadata)
print(f'\nКоличество объектов: {len(Yadata)}')
# Out:
# [{'_id': '94919465',
#   'date_time': '2020-04-19 15:00',
#   'link': 'https://yandex.ru/news/story/Peskov_dopustil_vykhod_na_pik_po_koronavirusu_na_sleduyushhej_nedele--1ea274cfa03bb38d6637001f68ec0efa?lang=ru&stid=-quPKXcAHqigTZqva9Kv&t=1587323615&tt=true&persistent_id=94919465',
#   'name': 'Песков допустил выход на пик по коронавирусу на следующей неделе',
#   'source': 'РИА Новости'},
#  {'_id': '94920274',
#   'date_time': '2020-04-19 16:25',
#   'link': 'https://yandex.ru/news/story/Siluanov_do_konca_goda_iz_FNB_potratyat_pochti_6_trln_rublej--1b51cb7e44aac8817f104971a359c6b4?lang=ru&stid=u3QnIkADsudK9vVPB2n3&t=1587323615&tt=true&persistent_id=94920274',
#   'name': 'Силуанов: до конца года из ФНБ потратят почти 6 трлн рублей',
#   'source': 'REGNUM'},
#  {'_id': '94927827',
#   'date_time': '2020-04-19 17:20',
#   'link': 'https://yandex.ru/news/story/Fizicheski_aktivnye_beremennye_myshi_zapasli_buryj_zhir_sebe_i_detyam--75b5c539afdc7a22a359cf14389bfbac?lang=ru&stid=Zxx9J7jaBTUS6pqeDQl9&t=1587323615&persistent_id=94812066',
#   'name': 'Физически активные беременные мыши запасли бурый жир себе и детям',
#   'source': 'N+1'},
#  {'_id': '94909951',
#   'date_time': '2020-04-19 11:05',
#   'link': 'https://yandex.ru/news/story/Putin_pozdravil_AvtoVAZ_s_50-letiem_vypuska_pervogo_avtomobilya--174b922ad5697e4ebcfd8b3af8baf2dc?lang=ru&stid=AnrkIcRd4ESaZsS-ss5_&t=1587323615&persistent_id=94909951',
#   'name': 'Путин поздравил «АвтоВАЗ» с 50-летием выпуска первого автомобиля',
#   'source': 'ТАСС'},
#  {'_id': '94265440',
#   'date_time': '2020-04-19 14:36',
#   'link': 'https://yandex.ru/news/story/V_GIBDD_nazvany_samye_nepopulyarnye_avtomobili_v_RF--76988d952859879fa567ac2acaea2341?lang=ru&stid=XnSVR_stAkenNh0l26Wv&t=1587323615&persistent_id=94265440',
#   'name': 'В ГИБДД названы самые непопулярные автомобили в РФ',
#   'source': 'Газета DAILY'},
#  {'_id': '94904443',
#   'date_time': '2020-04-19 16:06',
#   'link': 'https://yandex.ru/news/story/Krossover_Honda_Breeze_stal_populyarnee_Honda_CR-V--2059061dd3171d949bbd24d590447480?lang=ru&stid=JNEyFkcyzIws5IvHx3YP&t=1587323615&persistent_id=94904443',
#   'name': 'Кроссовер Honda Breeze стал популярнее Honda CR-V',
#   'source': 'Автоновости дня'},
#  {'_id': '94939261',
#   'date_time': '2020-04-19 19:12',
#   'link': 'https://yandex.ru/news/story/Ubijca_Patriota_vse_problemy_poderzhannogo_Great_Wall_Hover--fe2158610a30b47954ec3d4e3f4dbde4?lang=ru&stid=Z6ZM&t=1587323615&persistent_id=94939261',
#   'name': '«Убийца» «Патриота»: все проблемы подержанного Great Wall Hover',
#   'source': 'Российская газета'},
#  {'_id': '94336175',
#   'date_time': '2020-04-19 17:43',
#   'link': 'https://yandex.ru/news/story/Sostavlen_rejting_avtomobilej_dlya_ehkstremalnogo_vozhdeniya--4bb80de807bff87027c4242b847f3fc0?lang=ru&stid=jM9pAiz0I7mazcODe2tX&t=1587323615&persistent_id=94336175',
#   'name': 'Составлен рейтинг автомобилей для экстремального вождения',
#   'source': 'Политическая Экспертиза'}]
#
# Количество объектов: 65

# %%
mongo = ManagerMongoDB(Yadata).show_result()

pprint(mongo)
print(f'\nКоличество объектов: {len(mongo)}')
# Out:
# [{'_id': '41447768',
#   'date_time': '2020-04-18 23:46:54',
#   'link': 'https://news.mail.ru//society/41447768/',
#   'name': 'Пасхальное богослужение в храме Христа Спасителя',
#   'source': 'ТАСС'},
#  {'_id': '41445652',
#   'date_time': '2020-04-18 20:50:28',
#   'link': 'https://news.mail.ru//society/41445652/',
#   'name': 'Коронавирус COVID-19: главные события 18 апреля',
#   'source': 'Новости Mail.ru'},
#  {'_id': '41446112',
#   'date_time': '2020-04-18 19:58:11',
#   'link': 'https://news.mail.ru//economics/41446112/',
#   'name': 'Туристический сезон в Турции может быть открыт в конце мая',
#   'source': 'Коммерсантъ'},
#  {'_id': '41444458',
#   'date_time': '2020-04-18 17:36:29',
#   'link': 'https://news.mail.ru//society/41444458/',
#   'name': 'Что говорят предприниматели о карантине',
#   'source': 'Коммерсантъ'},
#  {'_id': '41444858',
#   'date_time': '2020-04-18 16:09:09',
#   'link': 'https://news.mail.ru//society/41444858/',
#   'name': 'COVID-19 породил новую экологическую проблему (фото)',
#   'source': 'Новости Mail.ru'},
#  {'_id': '41444334',
#   'date_time': '2020-04-18 16:55:28',
#   'link': 'https://news.mail.ru//incident/41444334/',
#   'name': 'Арестованы активы крупных российских компаний по вылову краба',
#   'source': 'Ведомости'},
#  {'_id': '41442103',
#   'date_time': '2020-04-18 12:58:34',
#   'link': 'https://news.mail.ru//society/41442103/',
#   'name': 'Путин разрешил принимать иностранцев без разрешения на работу',
#   'source': 'РИА Новости'},
#  {'_id': '41441693',
#   'date_time': '2020-04-18 10:47:11',
#   'link': 'https://news.mail.ru//incident/41441693/',
#   'name': 'В России за сутки выявлено более 4700 больных коронавирусом',
#   'source': 'Коммерсантъ'},
#  {'_id': '41447556',
#   'date_time': '2020-04-18 23:14:43',
#   'link': 'https://news.mail.ru//society/41447556/',
#   'name': 'Коронавирус: британские звезды устраивают большой онлайн-концерт',
#   'source': 'BBC News Русская служба'},
#  {'_id': '41442947',
#   'date_time': '2020-04-18 12:53:24',
#   'link': 'https://news.mail.ru//society/41442947/',
#   'name': 'Онищенко ответил на заявления Лукашенко о тестах на COVID-19',
#   'source': 'РИА Новости'},
#  {'_id': '41447158',
#   'date_time': '2020-04-18 21:32:11',
#   'link': 'https://news.mail.ru//incident/41447158/',
#   'name': 'В архангельской психбольнице зафиксировали вспышку коронавируса',
#   'source': 'ТАСС'},
#  {'_id': '41442413',
#   'date_time': '2020-04-18 12:04:03',
#   'link': 'https://news.mail.ru//society/41442413/',
#   'name': 'Россия вошла в топ-10 стран по числу заболевших вирусом COVID-19',
#   'source': 'Известия'},
#  {'_id': '41444717',
#   'date_time': '2020-04-18 16:05:22',
#   'link': 'https://news.mail.ru//economics/41444717/',
#   'name': 'Список пострадавших сфер экономики от пандемии расширен',
#   'source': 'Известия'},
#  {'_id': '41449639',
#   'date_time': '2020-04-19 09:20:49',
#   'link': 'https://news.mail.ru//politics/41449639/',
#   'name': 'Путин заявил о полном контроле над ситуацией с коронавирусом',
#   'source': 'РИА Новости'},
#  {'_id': '41448976',
#   'date_time': '2020-04-19 09:03:13',
#   'link': 'https://news.mail.ru//society/41448976/',
#   'name': 'Демограф оценила последствия коронавируса для рождаемости',
#   'source': 'Lenta.Ru'},
#  {'_id': '41448640',
#   'date_time': '2020-04-19 04:37:53',
#   'link': 'https://news.mail.ru//incident/41448640/',
#   'name': 'В Китае за сутки выявили 16 случаев заражения коронавирусом',
#   'source': 'РИА Новости'},
#  {'_id': '41448015',
#   'date_time': '2020-04-19 00:20:10',
#   'link': 'https://news.mail.ru//society/41448015/',
#   'name': 'Умер писатель и журналист Александр Кабаков',
#   'source': 'ТАСС'},
#  {'_id': '41447953',
#   'date_time': '2020-04-19 09:24:25',
#   'link': 'https://news.mail.ru//society/41447953/',
#   'name': 'Запад обвиняет Китай в искажении данных о коронавирусе',
#   'source': 'Lenta.Ru'},
#  {'_id': '41449362',
#   'date_time': '2020-04-19 08:28:22',
#   'link': 'https://news.mail.ru//economics/41449362/',
#   'name': 'США предрекли рекордный госдолг из-за коронавируса',
#   'source': 'Lenta.Ru'},
#  {'_id': '41447949',
#   'date_time': '2020-04-19 03:20:45',
#   'link': 'https://news.mail.ru//politics/41447949/',
#   'name': 'В Испании продлили режим повышенной готовности',
#   'source': 'Lenta.Ru'},
#  {'_id': '41448222',
#   'date_time': '2020-04-19 01:54:10',
#   'link': 'https://news.mail.ru//politics/41448222/',
#   'name': 'Трамп пообещал найти выделяемым ВОЗ $500 млн другое применение',
#   'source': 'ТАСС'},
#  {'_id': '41448412',
#   'date_time': '2020-04-19 03:09:35',
#   'link': 'https://news.mail.ru//economics/41448412/',
#   'name': 'Эксперт рассказал, как самозанятым получить кредитные каникулы',
#   'source': 'РИА Новости'},
#  {'_id': '41448888',
#   'date_time': '2020-04-19 06:37:25',
#   'link': 'https://news.mail.ru//incident/41448888/',
#   'name': 'Число жертв коронавируса в мире превысило 160 тысяч человек',
#   'source': 'Интерфакс'},
#  {'_id': '41449192',
#   'date_time': '2020-04-19 09:54:35',
#   'link': 'https://news.mail.ru//incident/41449192/',
#   'name': 'СМИ: США закупили респираторы по завышенной стоимости',
#   'source': 'ТАСС'},
#  {'_id': '41450074',
#   'date_time': '2020-04-19 10:30:27',
#   'link': 'https://news.mail.ru//politics/41450074/',
#   'name': 'Глава лаборатории в Ухане отверг обвинения в создании вируса',
#   'source': 'Lenta.Ru'},
#  {'_id': '41448505',
#   'date_time': 'Не получилось собрать дату публикации (тип ошибки: list index '
#                'out of range)',
#   'link': 'https://news.mail.ru/https://sportmail.ru/news/football-eurocups/41448505/',
#   'name': 'Стали известны даты возобновления Лиги чемпионов и Лиги Европы',
#   'source': 'Не получилось собрать источник публикации (тип ошибки: list index '
#             'out of range)'},
#  {'_id': '41448769',
#   'date_time': '2020-04-19 10:04:14',
#   'link': 'https://news.mail.ru//society/41448769/',
#   'name': 'Вулкан Ключевской выбросил потоки лавы (видео)',
#   'source': 'РИА Новости'},
#  {'_id': '41450650',
#   'date_time': '2020-04-19 12:14:39',
#   'link': 'https://news.mail.ru//society/41450650/',
#   'name': 'В России за сутки заразились коронавирусом 6060 человек',
#   'source': 'Ведомости'},
#  {'_id': '41452413',
#   'date_time': '2020-04-19 14:23:05',
#   'link': 'https://news.mail.ru//politics/41452413/',
#   'name': 'Песков рассказал, когда Россия выйдет на плато по коронавирусу',
#   'source': 'Известия'},
#  {'_id': '41450332',
#   'date_time': None,
#   'link': 'https://news.mail.ru/https://sportmail.ru/news/figure-skating/41450332/',
#   'name': 'Уехавший в США русский фигурист рассказал о панике американцев',
#   'source': None},
#  {'_id': '41451890',
#   'date_time': '2020-04-19 13:43:58',
#   'link': 'https://news.mail.ru//society/41451890/',
#   'name': 'Ученые получили новые данные о бессимптомном протекании COVID-19',
#   'source': 'Новости Mail.ru'},
#  {'_id': '41450047',
#   'date_time': '2020-04-19 10:55:35',
#   'link': 'https://news.mail.ru//society/41450047/',
#   'name': 'В РАН спрогнозировали масштаб второй волны коронавируса',
#   'source': 'm24.ru'},
#  {'_id': '41452118',
#   'date_time': '2020-04-19 14:34:53',
#   'link': 'https://news.mail.ru//politics/41452118/',
#   'name': 'Путин прокомментировал страхи по поводу возрождения СССР',
#   'source': 'ТАСС'},
#  {'_id': '41449873',
#   'date_time': '2020-04-19 10:41:12',
#   'link': 'https://news.mail.ru//society/41449873/',
#   'name': 'Насколько по-разному пандемия влияет на мужчин и женщин и почему',
#   'source': 'BBC News Русская служба'},
#  {'_id': '41451806',
#   'date_time': '2020-04-19 13:42:44',
#   'link': 'https://news.mail.ru//society/41451806/',
#   'name': 'Чубайс предсказал падение числа заражений коронавирусом в мае',
#   'source': 'Forbes'},
#  {'_id': '41450130',
#   'date_time': '2020-04-19 12:37:16',
#   'link': 'https://news.mail.ru//society/41450130/',
#   'name': 'Историк высмеял миф о насилии армии СССР над жителями Германии',
#   'source': 'РИА Новости'},
#  {'_id': '41450704',
#   'date_time': '2020-04-19 11:25:45',
#   'link': 'https://news.mail.ru//society/41450704/',
#   'name': 'В ЮАР на безлюдные улицы вышли пингвины (видео)',
#   'source': 'Новости Mail.ru'},
#  {'_id': '41452177',
#   'date_time': '2020-04-19 16:01:11',
#   'link': 'https://news.mail.ru//politics/41452177/',
#   'name': 'Песков: наступило время, которое требует ручного управления',
#   'source': 'РИА Новости'},
#  {'_id': '41452676',
#   'date_time': '2020-04-19 15:37:37',
#   'link': 'https://news.mail.ru//society/41452676/',
#   'name': 'Коронавирус оживил старый российский мем (фото)',
#   'source': 'Новости Mail.ru'},
#  {'_id': '41448513',
#   'date_time': '2020-04-19 14:18:53',
#   'link': 'https://news.mail.ru//society/41448513/',
#   'name': 'МЧС советует после покупки замачивать в воде овощи и зелень',
#   'source': 'ТАСС'},
#  {'_id': '41452605',
#   'date_time': '2020-04-19 15:19:00',
#   'link': 'https://news.mail.ru//economics/41452605/',
#   'name': 'Силуанов: в ФНБ к концу года останется 7 трлн рублей',
#   'source': 'Интерфакс'},
#  {'_id': '41453332',
#   'date_time': '2020-04-19 16:43:05',
#   'link': 'https://news.mail.ru//politics/41453332/',
#   'name': 'Российские военные испытали танк «Армата» в Сирии',
#   'source': 'Интерфакс'},
#  {'_id': '41453277',
#   'date_time': None,
#   'link': 'https://news.mail.ru/https://sportmail.ru/news/football-rus-premier/41453277/',
#   'name': 'РПЛ планирует возобновиться с середины июня по середину июля',
#   'source': None},
#  {'_id': '41453202',
#   'date_time': '2020-04-19 16:11:28',
#   'link': 'https://news.mail.ru//society/41453202/',
#   'name': 'Над Баварией появилось странное облако',
#   'source': 'Погода Mail.ru'},
#  {'_id': '41452672',
#   'date_time': '2020-04-19 16:35:56',
#   'link': 'https://news.mail.ru//economics/41452672/',
#   'name': 'Орешкин дал негативный прогноз на второй квартал по экономике',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/armata',
#   'date_time': '2020-04-19 16:40:00',
#   'link': 'https://lenta.ru//news/2020/04/19/armata/',
#   'name': 'Россия испытала танк «Армата» в Сирии',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/dog',
#   'date_time': '2020-04-19 17:26:00',
#   'link': 'https://lenta.ru//news/2020/04/19/dog/',
#   'name': 'Мужчина нашел на шоссе собаку с трогательной запиской и расплакался',
#   'source': 'Источник отсутствует'},
#  {'_id': '2020/04/19/aurus',
#   'date_time': '2020-04-19 17:11:06',
#   'link': 'https://lenta.ru//news/2020/04/19/aurus/',
#   'name': 'Стали известны сроки первой поставки машин из «Кортежа» Путина',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/chestno',
#   'date_time': '2020-04-19 17:03:00',
#   'link': 'https://lenta.ru//news/2020/04/19/chestno/',
#   'name': 'Идущий на шестой срок Лукашенко пообещал честные выборы',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/reanim',
#   'date_time': '2020-04-19 16:58:00',
#   'link': 'https://lenta.ru//news/2020/04/19/reanim/',
#   'name': 'Малышева показала реанимацию пациента в больнице с зараженными '
#           'коронавирусом',
#   'source': None},
#  {'_id': '2020/04/19/msk',
#   'date_time': '2020-04-19 16:30:00',
#   'link': 'https://lenta.ru//news/2020/04/19/msk/',
#   'name': 'Охлобыстин атаковал журналистку на пасхальной службе «для '
#           'избранных» в Москве',
#   'source': None},
#  {'_id': None,
#   'date_time': None,
#   'link': 'https://moslenta.ru/news/obnarodovana-novaya-statistika-po-koronavirusu-v-moskve-19-04-2020.htm/?utm_source=from_lenta',
#   'name': 'Обнародована новая статистика по коронавирусу в Москве ',
#   'source': None},
#  {'_id': '2020/04/19/easter2',
#   'date_time': '2020-04-19 16:11:00',
#   'link': 'https://lenta.ru//news/2020/04/19/easter2/',
#   'name': 'На службе «для избранных» в храме у Кремля молились прихожане на '
#           'Porsche',
#   'source': 'Источник отсутствует'},
#  {'_id': '2020/04/19/debilizacia',
#   'date_time': '2020-04-19 16:00:00',
#   'link': 'https://lenta.ru//news/2020/04/19/debilizacia/',
#   'name': 'Гузеева констатировала дебилизацию в стране',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/siluanov',
#   'date_time': '2020-04-19 15:14:00',
#   'link': 'https://lenta.ru//news/2020/04/19/siluanov/',
#   'name': 'Назван срок истощения российской «кубышки»',
#   'source': 'РИА Новости'},
#  {'_id': '2020/04/19/prognoz',
#   'date_time': '2020-04-19 17:29:43',
#   'link': 'https://lenta.ru//news/2020/04/19/prognoz/',
#   'name': 'Названы сроки возврата к нормальной жизни после эпидемии '
#           'коронавируса в России',
#   'source': 'РИА Новости'},
#  {'_id': '41453715',
#   'date_time': '2020-04-19 17:21:55',
#   'link': 'https://news.mail.ru//incident/41453715/',
#   'name': 'В Москве арестован грузинский криминальный авторитет',
#   'source': 'Коммерсантъ'},
#  {'_id': '41453467',
#   'date_time': '2020-04-19 17:03:58',
#   'link': 'https://news.mail.ru//society/41453467/',
#   'name': 'Ученые назвали тревожный симптом коронавируса',
#   'source': 'РИА Новости'},
#  {'_id': '94919465',
#   'date_time': '2020-04-19 15:00',
#   'link': 'https://yandex.ru/news/story/Peskov_dopustil_vykhod_na_pik_po_koronavirusu_na_sleduyushhej_nedele--1ea274cfa03bb38d6637001f68ec0efa?lang=ru&stid=-quPKXcAHqigTZqva9Kv&t=1587323615&tt=true&persistent_id=94919465',
#   'name': 'Песков допустил выход на пик по коронавирусу на следующей неделе',
#   'source': 'РИА Новости'},
#  {'_id': '94920274',
#   'source': 'REGNUM'},
#  {'_id': '94338335',
#   'date_time': '2020-04-19 12:03',
#   'link': 'https://yandex.ru/news/story/Talamus_vliyaet_na_prinyatie_reshenij_v_izmenyayushhikhsya_usloviyakh--fcc46372855cf9493f1a0b72b87cbb00?lang=ru&stid=oA8MF_RcOwCfpB6Svqnz&t=1587323615&persistent_id=94338335',
#   'name': 'Таламус влияет на принятие решений в изменяющихся условиях',
#   'source': 'ИА Красная Весна'},
#  {'_id': '94812066',
#   'date_time': '2020-04-19 21:00',
#   'link': 'https://yandex.ru/news/story/Fizicheski_aktivnye_beremennye_myshi_zapasli_buryj_zhir_sebe_i_detyam--75b5c539afdc7a22a359cf14389bfbac?lang=ru&stid=Zxx9J7jaBTUS6pqeDQl9&t=1587323615&persistent_id=94812066',
#   'name': 'Физически активные беременные мыши запасли бурый жир себе и детям',
#   'source': 'N+1'},
#  {'_id': '94909951',
#   'date_time': '2020-04-19 11:05',
#   'link': 'https://yandex.ru/news/story/Putin_pozdravil_AvtoVAZ_s_50-letiem_vypuska_pervogo_avtomobilya--174b922ad5697e4ebcfd8b3af8baf2dc?lang=ru&stid=AnrkIcRd4ESaZsS-ss5_&t=1587323615&persistent_id=94909951',
#   'name': 'Путин поздравил «АвтоВАЗ» с 50-летием выпуска первого автомобиля',
#   'source': 'ТАСС'},
#  {'_id': '94265440',
#   'date_time': '2020-04-19 14:36',
#   'link': 'https://yandex.ru/news/story/V_GIBDD_nazvany_samye_nepopulyarnye_avtomobili_v_RF--76988d952859879fa567ac2acaea2341?lang=ru&stid=XnSVR_stAkenNh0l26Wv&t=1587323615&persistent_id=94265440',
#   'name': 'В ГИБДД названы самые непопулярные автомобили в РФ',
#   'source': 'Газета DAILY'},
#  {'_id': '94904443',
#   'date_time': '2020-04-19 16:06',
#   'link': 'https://yandex.ru/news/story/Krossover_Honda_Breeze_stal_populyarnee_Honda_CR-V--2059061dd3171d949bbd24d590447480?lang=ru&stid=JNEyFkcyzIws5IvHx3YP&t=1587323615&persistent_id=94904443',
#   'name': 'Кроссовер Honda Breeze стал популярнее Honda CR-V',
#   'source': 'Автоновости дня'},
#  {'_id': '94939261',
#   'date_time': '2020-04-19 19:12',
#   'link': 'https://yandex.ru/news/story/Ubijca_Patriota_vse_problemy_poderzhannogo_Great_Wall_Hover--fe2158610a30b47954ec3d4e3f4dbde4?lang=ru&stid=Z6ZM&t=1587323615&persistent_id=94939261',
#   'name': '«Убийца» «Патриота»: все проблемы подержанного Great Wall Hover',
#   'source': 'Российская газета'},
#  {'_id': '94336175',
#   'date_time': '2020-04-19 17:43',
#   'link': 'https://yandex.ru/news/story/Sostavlen_rejting_avtomobilej_dlya_ehkstremalnogo_vozhdeniya--4bb80de807bff87027c4242b847f3fc0?lang=ru&stid=jM9pAiz0I7mazcODe2tX&t=1587323615&persistent_id=94336175',
#   'name': 'Составлен рейтинг автомобилей для экстремального вождения',
#   'source': 'Политическая Экспертиза'}]
#
# Количество объектов: 123
